# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("all_data.csv")

# %%
df
# Out:
#      Country  Year  Life expectancy at birth (years)           GDP
# 0      Chile  2000                              77.3  7.786093e+10
# 1      Chile  2001                              77.3  7.097992e+10
# 2      Chile  2002                              77.8  6.973681e+10
# 3      Chile  2003                              77.9  7.564346e+10
# 4      Chile  2004                              78.0  9.921039e+10
# ..       ...   ...                               ...           ...
# 91  Zimbabwe  2011                              54.9  1.209845e+10
# 92  Zimbabwe  2012                              56.6  1.424249e+10
# 93  Zimbabwe  2013                              58.0  1.545177e+10
# 94  Zimbabwe  2014                              59.2  1.589105e+10
# 95  Zimbabwe  2015                              60.7  1.630467e+10
#
# [96 rows x 4 columns]

# %%
print(df.Country.unique())
# Out:
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']

# %% [markdown]
# #### let's fix the column name (it's too long):

# %%
df.rename(columns={'Life expectancy at birth (years)': 'Life_exp'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Country   96 non-null     object
#  1   Year      96 non-null     int64
#  2   Life_exp  96 non-null     float64
#  3   GDP       96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB

# %%
df.describe()
# Out:
#               Year   Life_exp           GDP
# count    96.000000  96.000000  9.600000e+01
# mean   2007.500000  72.789583  3.880499e+12
# std       4.633971  10.672882  5.197561e+12
# min    2000.000000  44.300000  4.415703e+09
# 25%    2003.750000  74.475000  1.733018e+11
# 50%    2007.500000  76.750000  1.280220e+12
# 75%    2011.250000  78.900000  4.067510e+12
# max    2015.000000  81.000000  1.810000e+13

# %% [markdown]
# # Life expectancy

# %%
plt.figure(figsize=(9,7))
sns.lineplot(data=df,x="Year",y="Life_exp")
plt.xlabel("Year")
plt.ylabel("Life expectancy at birth (years)")
plt.title("life expectancy over time in the six nation")
# Out:
# Text(0.5, 1.0, 'life expectancy over time in the six nation')

# %%
plt.figure(figsize=(9,7))
sns.relplot(data=df,x="Year", y="Life_exp", hue="Country", kind="line")
plt.ylabel("Life expectancy at birth (years)")
plt.title("life expectancy over time in the six nation")
# Out:
# Text(0.5, 1.0, 'life expectancy over time in the six nation')

# %%
g = sns.FacetGrid(df,col="Country",col_wrap=3,sharey = False, sharex = False,hue="Country",height=4.5)
g.map(sns.lineplot,"Year","Life_exp")
g.add_legend()
g.set_xlabels("Life expectancy at birth (years)")
g.set_ylabels("GDP (trillion dollars)")
#g.set_title("life expectancy over time")
g.fig.subplots_adjust(top=0.9) # adjust the Figure in rp
g.fig.suptitle('Life expectancy over time')
# Out:
# Text(0.5, 0.98, 'Life expectancy over time')

# %%
plt.figure(figsize=(9,7))
ax = plt.subplot()
sns.boxplot(y="Life_exp",x="Country",data=df)
plt.ylabel("Life expectancy at birth (years)")
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Chile'),
#   Text(1, 0, 'China'),
#   Text(2, 0, 'Germany'),
#   Text(3, 0, 'Mexico'),
#   Text(4, 0, 'United States of America'),
#   Text(5, 0, 'Zimbabwe')])

# %%
plt.figure(figsize=(9,7))
ax = plt.subplot()
sns.boxplot(y="Life_exp",x="Country",data=df)
plt.ylabel("Life expectancy at birth (years)")
plt.xticks(rotation=90)
sns.stripplot(y="Life_exp", x="Country", data=df,
              size=3, color=".3", linewidth=1)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Life_exp'>

# %%
plt.figure(figsize=(9,7))
ax = plt.subplot()
sns.violinplot(y="Life_exp",x="Country",data=df)
plt.ylabel("Life expectancy at birth (years)")
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Chile'),
#   Text(1, 0, 'China'),
#   Text(2, 0, 'Germany'),
#   Text(3, 0, 'Mexico'),
#   Text(4, 0, 'United States of America'),
#   Text(5, 0, 'Zimbabwe')])

# %%
plt.figure(figsize=(9,7))
ax = plt.subplot()
sns.violinplot(y="Life_exp",x="Country",data=df)
plt.ylabel("Life expectancy at birth (years)")
plt.xticks(rotation=90)
sns.stripplot(y="Life_exp", x="Country", data=df,
              size=3, color=".8", linewidth=1)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Life_exp'>

# %% [markdown]
# # GDP

# %%
plt.figure(figsize=(9,7))
sns.lineplot(data=df,x="Year",y="GDP")
plt.xlabel("Year")
plt.ylabel("GDP (trillion dollars)")
plt.title("GDP over time in the six nation")
# Out:
# Text(0.5, 1.0, 'GDP over time in the six nation')

# %%
plt.figure(figsize=(9,7))
sns.relplot(data=df,x="Year", y="GDP", hue="Country", kind="line")
plt.xlabel("Year")
plt.ylabel("GDP (trillion dollars)")
plt.title("GDP over time in the six nation")
# Out:
# Text(0.5, 1.0, 'GDP over time in the six nation')

# %%
g = sns.FacetGrid(df,col="Country",col_wrap=3,sharey = False, sharex = False,hue="Country",height=4.5)
g.map(sns.lineplot,"Year","GDP")
g.add_legend()
g.set_xlabels("Year")
g.set_ylabels("GDP (trillion dollars)")

# %%
plt.figure(figsize=(9,7))
ax = plt.subplot()
sns.boxplot(y="GDP",x="Country",data=df)
plt.xticks(rotation=90)
plt.ylabel("GDP (trillion dollars)")
plt.title("GDP over time in the six nation")
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Chile'),
#   Text(1, 0, 'China'),
#   Text(2, 0, 'Germany'),
#   Text(3, 0, 'Mexico'),
#   Text(4, 0, 'United States of America'),
#   Text(5, 0, 'Zimbabwe')])

# %%
plt.figure(figsize=(9,7))
ax = plt.subplot()
sns.boxplot(y="GDP",x="Country",data=df)
plt.xticks(rotation=90)
sns.stripplot(y="GDP", x="Country", data=df,
              size=3, color=".3", linewidth=1)
plt.ylabel("GDP (trillion dollars)")
plt.title("GDP over time in the six nation")
# Out:
# <AxesSubplot:xlabel='Country', ylabel='GDP'>

# %%
plt.figure(figsize=(9,7))
ax = plt.subplot()
sns.violinplot(y="GDP",x="Country",data=df)
plt.xticks(rotation=90)
plt.ylabel("GDP (trillion dollars)")
plt.title("GDP over time in the six nation")
# Out:
# Text(0.5, 1.0, 'GDP over time in the six nation')

# %%
plt.figure(figsize=(9,7))
ax = plt.subplot()
sns.violinplot(y="GDP",x="Country",data=df)
plt.xticks(rotation=90)
sns.stripplot(y="GDP", x="Country", data=df,
              size=3, color=".3", linewidth=1)
plt.ylabel("GDP (trillion dollars)")
plt.title("GDP over time in the six nation")
# Out:
# Text(0.5, 1.0, 'GDP over time in the six nation')

# %% [markdown]
# # GDP and Life expectancy relation

# %%
plt.figure(figsize=(9,7))
sns.scatterplot(data=df,x="Life_exp", y="GDP",hue="Country")
plt.ylabel("Life expectancy at birth (years)")
# Out:
# Text(0, 0.5, 'Life expectancy at birth (years)')

# %%
g = sns.FacetGrid(df,col="Country",col_wrap=3,sharey = False, sharex = False,hue="Country",height=4.5)
g.map(sns.scatterplot,"Life_exp","GDP")
g.add_legend()
g.set_xlabels("Life expectancy at birth (years)")
g.set_ylabels("GDP (trillion dollars)")
